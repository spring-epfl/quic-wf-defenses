# %%
# imports and functions, does nothing

from IPython.display import Image
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from json import JSONEncoder
import json

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

def serialize(uri, o, version=''):
    try:
        os.remove(".cache/"+uri)
    except:
        pass
    with open(".cache/"+uri, "w") as f:
        if version != '':
            f.write('#version: '+version+'\n')
        json.dump(o, f, cls=NumpyArrayEncoder)

def deserialize(uri, version=''):
    if os.path.isfile(".cache/"+uri):
        with open(".cache/"+uri, "r") as f:
            data = []
            for line in f:
                if not line.startswith('#version:'):
                    data.append(line)
            return json.loads(''.join(data))
    return None

def load_or_compute(uri, compute_function, rebuild=False):
    data = None
    if not rebuild:
        data = deserialize(uri)
    if data is None:
        data = compute_function()
        serialize(uri, data)
        return data
    return data

def img(path, width=400):
    rnd = random.randint(0,2e9)
    return f"""<img src="{path}?nocache={rnd}" style="width:{width}px; "></img>"""

def plot_fi(features_of_interest, title):
    features_of_interest.sort(key=lambda row: row[1], reverse=True) # truncate top ten
    features_of_interest = features_of_interest[:10]
    features_of_interest.sort(key=lambda row: row[1], reverse=False) # plotting needs ascending order

    xs = [x[0] for x in features_of_interest]
    ys = [y[1] for y in features_of_interest]
    yerr = [[min(y[1], y[2]) for y in features_of_interest], [y[2] for y in features_of_interest]]

    plt.barh(xs, ys, xerr=yerr)
    plt.title(title)
    plt.show()

# %%
data_all = np.load('datasets/quic-100p-150-40runs-again.npy', allow_pickle=True).item()

def add(a, b):
    x = 0
    if a is not None:
        x += abs(a)
    if b is not None:
        x += abs(b)
    return x

def toOldHARFormat(data):
    data2 = {}
    for url in data:
        data2[url] = {}
        for sample in data[url]:
            data2[url][sample] = []
            for request in data[url][sample]:
                domain, fullurl, t, out_h, out_b, t_resp, inc_h, inc_b = request
                data2[url][sample].append([t, add(out_h, out_b), add(inc_h, inc_b)])
    return data2

# %%
from lib.features import *
from lib.rf import *

# %%
def attack_and_plot(data, title):
    features = get_features(data)
    clf_res = rf_with_rfe(features, n_classes=141)
    print(clf_res)
    plot_fi(clf_res['features'], title=title)
    return clf_res

clf_results = {}
for data_type in data_all:

    data = toOldHARFormat(data_all[data_type])

    features = get_features(data)
    clf_res = rf_with_rfe(features, n_classes=141)
    print(data_type, clf_res)

    clf_results[data_type] = clf_res

np.save('datasets/variants.npy', clf_results)
# Out:
# Skipping guestnode.com , 15 empty samples
# Skipping school54.ks.ua , 25 empty samples
# Skipping ragazzeconlavaligia.com , 14 empty samples
# Skipping funakoshikarateaustralia.com.au , 24 empty samples
# [feature_extract] Number of classes 131
# [feature_extract] Number of features 123
# [feature_extract] Number of samples 5211
# [feature_extract] Number of labels 5211
# Number of classes 131
# Number of features 123
# Number of samples 5211
# Number of labels 5211
# Fold 0
# 141 but only found 131
# Scores were 0.9712368168744008 but were corrected to 0.9620132953466287.
# Fold 1
# 141 but only found 131
# Scores were 0.9789069990412272 but were corrected to 0.9696106362773029.
# Fold 2
# 141 but only found 131
# Scores were 0.9702780441035475 but were corrected to 0.9610636277302944.
# Fold 3
# 141 but only found 131
# Scores were 0.9664429530201343 but were corrected to 0.9572649572649573.
# Fold 4
# 141 but only found 131
# Scores were 0.9674017257909875 but were corrected to 0.9582146248812915.
# Fold 5
# 141 but only found 131
# Scores were 0.9741131351869607 but were corrected to 0.9648622981956315.
# Fold 6
# 141 but only found 131
# Scores were 0.9856184084372004 but were corrected to 0.976258309591643.
# Fold 7
# 141 but only found 131
# Scores were 0.9789069990412272 but were corrected to 0.9696106362773029.
# Fold 8
# 141 but only found 131
# Scores were 0.9693192713326941 but were corrected to 0.9601139601139601.
# Fold 9
# 141 but only found 131
# Scores were 0.962607861936721 but were corrected to 0.95346628679962.
# adblock {'score': {'accuracy': (0.963247863247863, 0.006525121894131777), 'precision': (0.963247863247863, 0.006525121894131777), 'recall': (0.963247863247863, 0.006525121894131777), 'f1score': (0.963247863247863, 0.006525121894131794)}, 'features': [('bytes_outgoing', 0.12476086063364693, 0.004617422364176671), ('bytes_%_in', 0.12241065819308142, 0.004656455525946866), ('bytes_%_out', 0.11497030310996488, 0.004779086696079367), ('bytes_total', 0.11268295178696283, 0.004528234548191327), ('bytes_incoming', 0.11161505258291708, 0.005157848475027624), ('hist_2341', 0.09313546033285214, 0.004704736872853862), ('n_outgoing', 0.07468584991571173, 0.038111321724890006), ('hist_2675', 0.07655746544875365, 0.004282347321477325), ('n_total', 0.0446779378267588, 0.04543260057059857), ('times_sum', 0.008005465623048238, 0.024016396869144713), ('hist_2006', 0.05253112696826949, 0.03453877942534887), ('hist_1672', 0.02544431996801665, 0.03117277643273539), ('n_incoming', 0.02569849079920746, 0.03961300860038845), ('hist_3009', 0.01282405681080872, 0.02565692037307084)]}
# Skipping guestnode.com , 17 empty samples
# Skipping school54.ks.ua , 20 empty samples
# Skipping ragazzeconlavaligia.com , 18 empty samples
# Skipping funakoshikarateaustralia.com.au , 19 empty samples
# Skipping digitalvin.com only 2 samples
# [feature_extract] Number of classes 131
# [feature_extract] Number of features 123
# [feature_extract] Number of samples 5209
# [feature_extract] Number of labels 5209
# Number of classes 131
# Number of features 123
# Number of samples 5209
# Number of labels 5209
# Fold 0
# 141 but only found 131
# Scores were 0.9731285988483686 but were corrected to 0.9638783269961977.
# Fold 1
# 141 but only found 131
# Scores were 0.974088291746641 but were corrected to 0.964828897338403.
# Fold 2
# 141 but only found 131
# Scores were 0.9683301343570058 but were corrected to 0.9591254752851711.
# Fold 3
# 141 but only found 131
# Scores were 0.972168905950096 but were corrected to 0.9629277566539924.
# Fold 4
# 141 but only found 131
# Scores were 0.9702495201535508 but were corrected to 0.9610266159695817.
# Fold 5
# 141 but only found 131
# Scores were 0.9875239923224568 but were corrected to 0.9781368821292775.
# Fold 6
# 141 but only found 131
# Scores were 0.9769673704414588 but were corrected to 0.967680608365019.
# Fold 7
# 141 but only found 131
# Scores were 0.9712092130518234 but were corrected to 0.9619771863117871.
# Fold 8
# 141 but only found 131
# Scores were 0.9692898272552783 but were corrected to 0.9600760456273765.
# Fold 9
# 141 but only found 131
# Scores were 0.974088291746641 but were corrected to 0.964828897338403.
# both {'score': {'accuracy': (0.9644486692015211, 0.005157665386407031), 'precision': (0.9644486692015211, 0.005157665386407031), 'recall': (0.9644486692015211, 0.005157665386407031), 'f1score': (0.9644486692015211, 0.005157665386407031)}, 'features': [('bytes_outgoing', 0.1262863455182144, 0.005622166154512651), ('bytes_total', 0.11386810260893394, 0.0033270318937579533), ('bytes_%_out', 0.11321839019624483, 0.00585723847553126), ('bytes_%_in', 0.11621653352234092, 0.004585988850164618), ('bytes_incoming', 0.11290960372377586, 0.0033070187835742212), ('hist_2341', 0.09405910920936736, 0.0023878980372558285), ('hist_2675', 0.07703053967210981, 0.007151779887385644), ('n_incoming', 0.07189109186219228, 0.03686427996706904), ('n_outgoing', 0.04428164821720186, 0.044871529671465946), ('hist_2006', 0.06596306616860471, 0.022119375666398017), ('time_outgoing_p75', 0.008225509359827049, 0.024676528079481144), ('n_total', 0.042056811780159256, 0.04228118397482599), ('times_sum', 0.008351349458412424, 0.02505404837523727), ('hist_1672', 0.0056418987026153, 0.0169256961078459)]}
# Skipping guestnode.com , 10 empty samples
# Skipping school54.ks.ua , 23 empty samples
# Skipping ragazzeconlavaligia.com , 21 empty samples
# Skipping funakoshikarateaustralia.com.au , 21 empty samples
# Skipping myegypthost.com , 38 empty samples
# Skipping hpsconline.in only 14 samples
# Skipping wewebit.com only 17 samples
# Skipping digitalvin.com only 1 samples
# Skipping ksgroupscans.com only 1 samples
# [feature_extract] Number of classes 128
# [feature_extract] Number of features 123
# [feature_extract] Number of samples 4959
# [feature_extract] Number of labels 4959
# Number of classes 128
# Number of features 123
# Number of samples 4959
# Number of labels 4959
# Fold 0
# 141 but only found 128
# Scores were 0.9737903225806451 but were corrected to 0.9611940298507463.
# Fold 1
# 141 but only found 128
# Scores were 0.9768145161290323 but were corrected to 0.9641791044776119.
# Fold 2
# 141 but only found 128
# Scores were 0.969758064516129 but were corrected to 0.9572139303482587.
# Fold 3
# 141 but only found 128
# Scores were 0.967741935483871 but were corrected to 0.9552238805970149.
# Fold 4
# 141 but only found 128
# Scores were 0.9727822580645161 but were corrected to 0.9601990049751243.
# Fold 5
# 141 but only found 128
# Scores were 0.9818548387096774 but were corrected to 0.9691542288557214.
# Fold 6
# 141 but only found 128
# Scores were 0.967741935483871 but were corrected to 0.9552238805970149.
# Fold 7
# 141 but only found 128
# Scores were 0.9647177419354839 but were corrected to 0.9522388059701492.
# Fold 8
# 141 but only found 128
# Scores were 0.9596774193548389 but were corrected to 0.9472636815920398.
# Fold 9
# 141 but only found 128
# Scores were 0.9616935483870968 but were corrected to 0.9492537313432836.
# nofilter {'score': {'accuracy': (0.9571144278606966, 0.006409227030920575), 'precision': (0.9571144278606966, 0.006409227030920575), 'recall': (0.9571144278606966, 0.006409227030920575), 'f1score': (0.9571144278606966, 0.006409227030920575)}, 'features': [('bytes_incoming', 0.13027037835575814, 0.004790162969797496), ('bytes_total', 0.12446078396517894, 0.005568285337960768), ('bytes_%_out', 0.11046585474217967, 0.004204146618551185), ('bytes_%_in', 0.10919434223917612, 0.004911370106847781), ('bytes_outgoing', 0.10196299517484357, 0.0036764174954517542), ('hist_2341', 0.05373004305327291, 0.04392990389555111), ('hist_2006', 0.09324319483318545, 0.006204306947228212), ('hist_2675', 0.0847221579008576, 0.0031485785672519463), ('n_outgoing', 0.08870091111223129, 0.009739277388858238), ('n_incoming', 0.06129583952906488, 0.03106014871078427), ('hist_3009', 0.00707981031664043, 0.021239430949921288), ('n_total', 0.028661355138103594, 0.03516127334744954), ('hist_1672', 0.006212333639507423, 0.01863700091852227)]}
# Skipping guestnode.com , 12 empty samples
# Skipping school54.ks.ua , 31 empty samples
# Skipping ragazzeconlavaligia.com , 24 empty samples
# Skipping funakoshikarateaustralia.com.au , 25 empty samples
# Skipping myegypthost.com , 39 empty samples
# Skipping wewebit.com only 19 samples
# [feature_extract] Number of classes 129
# [feature_extract] Number of features 123
# [feature_extract] Number of samples 4966
# [feature_extract] Number of labels 4966
# Number of classes 129
# Number of features 123
# Number of samples 4966
# Number of labels 4966
# Fold 0
# 141 but only found 129
# Scores were 0.9738430583501007 but were corrected to 0.9622266401590457.
# Fold 1
# 141 but only found 129
# Scores were 0.9698189134808853 but were corrected to 0.9582504970178927.
# Fold 2
# 141 but only found 129
# Scores were 0.9728370221327968 but were corrected to 0.9612326043737575.
# Fold 3
# 141 but only found 129
# Scores were 0.971830985915493 but were corrected to 0.9602385685884692.
# Fold 4
# 141 but only found 129
# Scores were 0.9708249496981891 but were corrected to 0.9592445328031809.
# Fold 5
# 141 but only found 129
# Scores were 0.9758551307847082 but were corrected to 0.9642147117296223.
# Fold 6
# 141 but only found 129
# Scores were 0.9728370221327968 but were corrected to 0.9612326043737575.
# Fold 7
# 141 but only found 129
# Scores were 0.9668008048289738 but were corrected to 0.9552683896620279.
# Fold 8
# 141 but only found 129
# Scores were 0.9698189134808853 but were corrected to 0.9582504970178927.
# Fold 9
# 141 but only found 129
# Scores were 0.9678068410462777 but were corrected to 0.9562624254473161.
# decentraleyes {'score': {'accuracy': (0.9596421471172961, 0.0025997409206007867), 'precision': (0.9596421471172961, 0.0025997409206007867), 'recall': (0.9596421471172961, 0.0025997409206007867), 'f1score': (0.9596421471172961, 0.0025997409206007867)}, 'features': [('bytes_total', 0.12224941202553359, 0.00461488180572059), ('bytes_incoming', 0.12284740031208655, 0.0040959655218868645), ('bytes_%_out', 0.10802004996187504, 0.006231489473953514), ('bytes_%_in', 0.10748046952254, 0.005272658300809229), ('bytes_outgoing', 0.1016924939538161, 0.0031386756705886285), ('hist_2341', 0.07321306253577944, 0.03664637864826189), ('n_total', 0.05081434124625844, 0.04208515146594376), ('hist_2006', 0.0917742764013137, 0.0056210754148649225), ('n_incoming', 0.07098947903713428, 0.03657179318947919), ('hist_2675', 0.08354656765281612, 0.004919836554334153), ('n_outgoing', 0.060290812036377026, 0.03970714184880612), ('hist_1672', 0.0070816353144697195, 0.02124490594340916)]}

# %%
for variant in clf_results:
    print(variant, clf_results[variant]['score']['f1score'])
# Out:
# adblock {'accuracy': (0.963247863247863, 0.006525121894131777), 'precision': (0.963247863247863, 0.006525121894131777), 'recall': (0.963247863247863, 0.006525121894131777), 'f1score': (0.963247863247863, 0.006525121894131794)}
# both {'accuracy': (0.9644486692015211, 0.005157665386407031), 'precision': (0.9644486692015211, 0.005157665386407031), 'recall': (0.9644486692015211, 0.005157665386407031), 'f1score': (0.9644486692015211, 0.005157665386407031)}
# nofilter {'accuracy': (0.9571144278606966, 0.006409227030920575), 'precision': (0.9571144278606966, 0.006409227030920575), 'recall': (0.9571144278606966, 0.006409227030920575), 'f1score': (0.9571144278606966, 0.006409227030920575)}
# decentraleyes {'accuracy': (0.9596421471172961, 0.0025997409206007867), 'precision': (0.9596421471172961, 0.0025997409206007867), 'recall': (0.9596421471172961, 0.0025997409206007867), 'f1score': (0.9596421471172961, 0.0025997409206007867)}
